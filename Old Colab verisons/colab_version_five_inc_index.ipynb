# %% [markdown]
# #Imports

# %%
import sys
from collections import Counter, OrderedDict
import itertools
from itertools import islice, count, groupby
import pandas as pd
import os
import re
from operator import itemgetter
import nltk
from nltk.stem.porter import *
from nltk.corpus import stopwords
from time import time
from timeit import timeit
from pathlib import Path
import pickle
import pandas as pd
import numpy as np
from google.cloud import storage
import math
nltk.download('stopwords')
import builtins
from numpy import dot
from numpy.linalg import norm

import numpy as np
import pandas as pd
# %load_ext google.colab.data_table
import bz2
from functools import partial
from collections import Counter, OrderedDict
import pickle
import heapq
from itertools import islice, count, groupby
from xml.etree import ElementTree
import codecs
import csv
import os
import re
from operator import itemgetter
import nltk
from nltk.stem.porter import *
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
# %matplotlib inline
from pathlib import Path
import itertools
from time import time
import hashlib
def _hash(s):
    return hashlib.blake2b(bytes(s, encoding='utf8'), digest_size=5).hexdigest()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# #helper functions

# %%
def flatten_lst(t):
    return [item for sublist in t for item in sublist]

# %%
def unq(list1):
 
    # initialize a null list
    unique_list = []
     
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)
    return unique_list

# %% [markdown]
# #getting json query data

# %%
import json


with open('queries_train.json', 'rt') as f:
  queries_to_docs_raw = json.load(f)

doc_lst=flatten_lst([docs for q,docs in queries_to_docs_raw.items()])

# %% [markdown]
# #**index from assignment 2**

# %%
import sys
from collections import Counter, OrderedDict, defaultdict
import itertools
from itertools import islice, count, groupby
import os
import re
from operator import itemgetter
from pathlib import Path
import pickle
from contextlib import closing

BLOCK_SIZE = 1999998

class MultiFileWriter:
    """ Sequential binary writer to multiple files of up to BLOCK_SIZE each. """
    def __init__(self, base_dir, name):
        self._base_dir = Path(base_dir)
        self._name = name
        self._file_gen = (open(self._base_dir / f'{name}_{i:03}.bin', 'wb') 
                          for i in itertools.count())
        self._f = next(self._file_gen)
    
    def write(self, b):
      locs = []
      while len(b) > 0:
        pos = self._f.tell()
        remaining = BLOCK_SIZE - pos
        # if the current file is full, close and open a new one.
        if remaining == 0:  
          self._f.close()
          self._f = next(self._file_gen)
          pos, remaining = 0, BLOCK_SIZE
        self._f.write(b[:remaining])
        locs.append((self._f.name, pos))
        b = b[remaining:]
      return locs

    def close(self):
      self._f.close()

class MultiFileReader:
  """ Sequential binary reader of multiple files of up to BLOCK_SIZE each. """
  def __init__(self):
    self._open_files = {}

  def read(self, locs, n_bytes):
    b = []
    for f_name, offset in locs:
      if f_name not in self._open_files:
        self._open_files[f_name] = open(f_name, 'rb')
      f = self._open_files[f_name]
      f.seek(offset)
      n_read = builtins.min(n_bytes, BLOCK_SIZE - offset)
      b.append(f.read(n_read))
      n_bytes -= n_read
    return b''.join(b)
  
  def close(self):
    for f in self._open_files.values():
      f.close()

  def __exit__(self, exc_type, exc_value, traceback):
    self.close()
    return False

TUPLE_SIZE = 6       # We're going to pack the doc_id and tf values in this 
                     # many bytes.
TF_MASK = 2 ** 16 - 1 # Masking the 16 low bits of an integer

class InvertedIndex:  
  def __init__(self, docs={}):
    """ Initializes the inverted index and add documents to it (if provided).
    Parameters:
    -----------
      docs: dict mapping doc_id to list of tokens
    """
    # stores document frequency per term
    self.df = Counter()
    # stores total frequency per term
    self.term_total = Counter()
    # stores posting list per term while building the index (internally), 
    # otherwise too big to store in memory.
    self._posting_list = defaultdict(list)
    # mapping a term to posting file locations, which is a list of 
    # (file_name, offset) pairs. Since posting lists are big we are going to
    # write them to disk and just save their location in this list. We are 
    # using the MultiFileWriter helper class to write fixed-size files and store
    # for each term/posting list its list of locations. The offset represents 
    # the number of bytes from the beginning of the file where the posting list
    # starts. 
    self.posting_locs = defaultdict(list)


    
    for doc_id, tokens in docs.items():
      self.add_doc(doc_id, tokens)

  def add_doc(self, doc_id, tokens):
    """ Adds a document to the index with a given `doc_id` and tokens. It counts
        the tf of tokens, then update the index (in memory, no storage 
        side-effects).
    """
    w2cnt = Counter(tokens)
    self.term_total.update(w2cnt)
    for w, cnt in w2cnt.items():
      self.df[w] = self.df.get(w, 0) + 1
      self._posting_list[w].append((doc_id, cnt))

  def write_index(self, base_dir, name):
    """ Write the in-memory index to disk. Results in the file: 
        (1) `name`.pkl containing the global term stats (e.g. df).
    """
    self._write_globals(base_dir, name)

  def _write_globals(self, base_dir, name):
    with open(Path(base_dir) / f'{name}.pkl', 'wb') as f:
      pickle.dump(self, f)

  def __getstate__(self):
    """ Modify how the object is pickled by removing the internal posting lists
        from the object's state dictionary. 
    """
    state = self.__dict__.copy()
    del state['_posting_list']
    return state

  def posting_lists_iter(self):
    """ A generator that reads one posting list from disk and yields 
        a (word:str, [(doc_id:int, tf:int), ...]) tuple.
    """
    with closing(MultiFileReader()) as reader:
      for w, locs in self.posting_locs.items():
        b = reader.read(locs, self.df[w] * TUPLE_SIZE)
        posting_list = []
        for i in range(self.df[w]):
          doc_id = int.from_bytes(b[i*TUPLE_SIZE:i*TUPLE_SIZE+4], 'big')
          tf = int.from_bytes(b[i*TUPLE_SIZE+4:(i+1)*TUPLE_SIZE], 'big')
          posting_list.append((doc_id, tf))
        yield w, posting_list


  @staticmethod
  def read_index(base_dir, name):
    with open(Path(base_dir) / f'{name}.pkl', 'rb') as f:
      return pickle.load(f)

  @staticmethod
  def delete_index(base_dir, name):
    path_globals = Path(base_dir) / f'{name}.pkl'
    path_globals.unlink()
    for p in Path(base_dir).rglob(f'{name}_*.bin'):
      p.unlink()


  @staticmethod
  def write_a_posting_list(b_w_pl,location):
    ''' Takes a (bucket_id, [(w0, posting_list_0), (w1, posting_list_1), ...]) 
    and writes it out to disk as files named {bucket_id}_XXX.bin under the 
    current directory. Returns a posting locations dictionary that maps each 
    word to the list of files and offsets that contain its posting list.
    Parameters:
    -----------
      b_w_pl: tuple
        Containing a bucket id and all (word, posting list) pairs in that bucket
        (bucket_id, [(w0, posting_list_0), (w1, posting_list_1), ...])
    Return:
      posting_locs: dict
        Posting locations for each of the words written out in this bucket.
    '''
    posting_locs = defaultdict(list)
    bucket, list_w_pl = b_w_pl

    with closing(MultiFileWriter(location, bucket)) as writer:
      for w, pl in list_w_pl: 
        # convert to bytes
        b = b''.join([(doc_id << 16 | (tf & TF_MASK)).to_bytes(TUPLE_SIZE, 'big')
                      for doc_id, tf in pl])
        # write to file(s)
        locs = writer.write(b)
      # save file locations to index
        posting_locs[w].extend(locs)
    return posting_locs

# %% [markdown]
# # pyspark crap and getting data from the bucket

# %%
# !pip install -q pyspark
# !pip install -U -q PyDrive
# !apt-get update
# !apt install openjdk-8-jdk-headless -qq
# !pip install -q graphframes
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
graphframes_jar = 'https://repos.spark-packages.org/graphframes/graphframes/0.8.2-spark3.2-s_2.12/graphframes-0.8.2-spark3.2-s_2.12.jar'
spark_jars = '/usr/local/lib/python3.7/dist-packages/pyspark/jars'
# !wget -N -P $spark_jars $graphframes_jar
import pyspark
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext
from pyspark.ml.feature import Tokenizer, RegexTokenizer
from graphframes import *
# Out:
#      |████████████████████████████████| 281.3 MB 39 kB/s
#      |████████████████████████████████| 198 kB 65.5 MB/s
#   Building wheel for pyspark (setup.py) ... done
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Hit:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Get:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [26.8 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [716 kB]
# Get:18 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,822 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,459 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,927 kB]
# Get:21 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,489 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [749 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [34.5 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,238 kB]
# Get:25 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [934 kB]
# Get:26 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [45.3 kB]
# Get:27 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [44.7 kB]
# Fetched 13.7 MB in 5s (2,747 kB/s)
# Reading package lists... Done
# The following additional packages will be installed:
#   openjdk-8-jre-headless
# Suggested packages:
#   openjdk-8-demo openjdk-8-source libnss-mdns fonts-dejavu-extra
#   fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   fonts-wqy-zenhei fonts-indic
# The following NEW packages will be installed:
#   openjdk-8-jdk-headless openjdk-8-jre-headless
# 0 upgraded, 2 newly installed, 0 to remove and 59 not upgraded.
# Need to get 36.5 MB of archives.
# After this operation, 143 MB of additional disk space will be used.
# Selecting previously unselected package openjdk-8-jre-headless:amd64.
# (Reading database ... 155225 files and directories currently installed.)
# Preparing to unpack .../openjdk-8-jre-headless_8u312-b07-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-8-jre-headless:amd64 (8u312-b07-0ubuntu1~18.04) ...
# Selecting previously unselected package openjdk-8-jdk-headless:amd64.
# Preparing to unpack .../openjdk-8-jdk-headless_8u312-b07-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-8-jdk-headless:amd64 (8u312-b07-0ubuntu1~18.04) ...
# Setting up openjdk-8-jre-headless:amd64 (8u312-b07-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/orbd to provide /usr/bin/orbd (orbd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/servertool to provide /usr/bin/servertool (servertool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/tnameserv to provide /usr/bin/tnameserv (tnameserv) in auto mode
# Setting up openjdk-8-jdk-headless:amd64 (8u312-b07-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/idlj to provide /usr/bin/idlj (idlj) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/wsimport to provide /usr/bin/wsimport (wsimport) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jsadebugd to provide /usr/bin/jsadebugd (jsadebugd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/native2ascii to provide /usr/bin/native2ascii (native2ascii) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/javah to provide /usr/bin/javah (javah) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/hsdb to provide /usr/bin/hsdb (hsdb) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/clhsdb to provide /usr/bin/clhsdb (clhsdb) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/xjc to provide /usr/bin/xjc (xjc) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/schemagen to provide /usr/bin/schemagen (schemagen) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/extcheck to provide /usr/bin/extcheck (extcheck) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jhat to provide /usr/bin/jhat (jhat) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/wsgen to provide /usr/bin/wsgen (wsgen) in auto mode
#      |████████████████████████████████| 154 kB 7.6 MB/s
# --2022-01-05 13:20:23--  https://repos.spark-packages.org/graphframes/graphframes/0.8.2-spark3.2-s_2.12/graphframes-0.8.2-spark3.2-s_2.12.jar
# Resolving repos.spark-packages.org (repos.spark-packages.org)... 13.226.228.23, 13.226.228.36, 13.226.228.104, ...
# Connecting to repos.spark-packages.org (repos.spark-packages.org)|13.226.228.23|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 247880 (242K) [binary/octet-stream]
# Saving to: ‘/usr/local/lib/python3.7/dist-packages/pyspark/jars/graphframes-0.8.2-spark3.2-s_2.12.jar’
#
# graphframes-0.8.2-s 100%[===================>] 242.07K  --.-KB/s    in 0.02s
#
# 2022-01-05 13:20:23 (9.88 MB/s) - ‘/usr/local/lib/python3.7/dist-packages/pyspark/jars/graphframes-0.8.2-spark3.2-s_2.12.jar’ saved [247880/247880]

# %%
# Initializing spark context
# create a spark context and session
conf = SparkConf().set("spark.ui.port", "4050")
sc = SparkContext.getOrCreate(conf=conf)
sc.addPyFile(str(Path(spark_jars) / Path(graphframes_jar).name))
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# Copying Wikidata

# %%
# Authenticate your user
# The authentication should be done with the email connected to your GCP account
from google.colab import auth
auth.authenticate_user()

# %%
# Copy one wikidumps files 
import os
from pathlib import Path
from google.colab import auth

project_id = 'core-period-321814'
# !gcloud config set project {project_id}

data_bucket_name = 'wikidata_preprocessed'
try:
    if os.environ["wikidata_preprocessed"] is not None:
        pass  
except:
      # !mkdir wikidumps
      # !gsutil cp gs://{data_bucket_name}/multistream1_preprocessed.parquet "wikidumps/"
# Out:
# Updated property [core/project].
# WARNING: You do not appear to have access to project [core-period-321814] or it does not exist.
# Copying gs://wikidata_preprocessed/multistream1_preprocessed.parquet...
# / [1 files][316.7 MiB/316.7 MiB]
# Operation completed over 1 objects/316.7 MiB.

# %% [markdown]
# #getting wiki data

# %%
from pathlib import Path 
import os

try:
    if os.environ["wikidata_preprocessed"] is not None:
      path = os.environ["wikidata_preprocessed"]+"/wikidumps/*"
except:
      path = "wikidumps/*"

parquetFile = spark.read.parquet(path)
wiki_data_body = parquetFile.select("id","text").rdd.filter(lambda x: x[0] in doc_lst)
wiki_data_anchor = parquetFile.select("id","anchor_text").rdd.filter(lambda x: x[0] in doc_lst)
wiki_data_title = parquetFile.select("id","title").rdd.filter(lambda x: x[0] in doc_lst)

# %% [markdown]
# #tf,df and other helpers

# %%
english_stopwords = frozenset(stopwords.words('english'))
corpus_stopwords = ["category", "references", "also", "external", "links", #TODO: CHECK IF NEED TO ADD
                    "may", "first", "see", "history", "people", "one", "two", 
                    "part", "thumb", "including", "second", "following", 
                    "many", "however", "would", "became"]
all_stopwords = english_stopwords.union(corpus_stopwords)
RE_WORD = re.compile(r"""[\#\@\w](['\-]?\w){2,24}""", re.UNICODE)

NUM_BUCKETS = 124
def token2bucket_id(token):
  return int(_hash(token),16) % NUM_BUCKETS

# Calc TF
# Returns a list of (token, (doc_id, tf)) pairs for each token (word) in the text
def word_count(id,text):
  ''' Count the frequency of each word in `text` (tf) that is not included in 
  `all_stopwords` and return entries that will go into our posting lists. 
  Parameters:
  -----------
    text: str
      Text of one document
    id: int
      Document id
  Returns:
  --------
    List of tuples
      A list of (token, (doc_id, tf)) pairs 
      for example: [("Anarchism", (12, 5)), ...]
  '''
  tokens = [token.group() for token in RE_WORD.finditer(text.lower())]
 
  terms = {}
  tf = Counter()
  for token in tokens:
    if token in all_stopwords:
      continue
    current = tf.get(token, 0)
    tf[token] = current + 1
    terms[token] = (id,current +1)


  return list(terms.items())

# Returns a sorted posting list from an unsorted posting list. Sorting by tf of doc id
def reduce_word_counts(unsorted_pl):
  ''' Returns a sorted posting list by wiki_id.
  Parameters:
  -----------
    unsorted_pl: list of tuples
      A list of (wiki_id, tf) tuples 
  Returns:
  --------
    list of tuples
      A sorted posting list.
  '''

  return(sorted(unsorted_pl, key = lambda x: x[0]))

def calculate_df(postings):
  ''' Takes a posting list RDD and calculate the df for each token.
  Parameters:
  -----------
    postings: RDD
      An RDD where each element is a (token, posting_list) pair.
  Returns:
  --------
    RDD
      An RDD where each element is a (token, df) pair.
  '''
  # YOUR CODE HERE
  return postings.map(lambda x: (x[0],len(x[1]))).partitionBy(16)

def partition_postings_and_write(postings,location):
  ''' A function that partitions the posting lists into buckets, writes out 
  all posting lists in a bucket to disk, and returns the posting locations for 
  each bucket. Partitioning should be done through the use of `token2bucket` 
  above. Writing to disk should use the function  `write_a_posting_list`, a 
  static method implemented in inverted_index_colab.py under the InvertedIndex 
  class. 
  Parameters:
  -----------
    postings: RDD
      An RDD where each item is a (w, posting_list) pair.
  Returns:
  --------
    RDD
      An RDD where each item is a posting locations dictionary for a bucket. The
      posting locations maintain a list for each word of file locations and 
      offsets its posting list was written to. See `write_a_posting_list` for 
      more details.
  '''
  res = defaultdict(list)
  output_list = []
  bucketed_postings = postings.map(lambda x:(token2bucket_id(x[0]),x)).groupByKey()
  for id,content in bucketed_postings.toLocalIterator():
    #output_list.append(InvertedIndex.write_a_posting_list((id,content),"208994616")) #for gcp ########################################################
    output_list.append(InvertedIndex.write_a_posting_list((id,content),location))
  sc = SparkContext.getOrCreate(SparkConf().setMaster("local[*]"))
  return sc.parallelize(output_list,numSlices=16)

# %% [markdown]
# #building the index : <font color='red'>no need</font>
#
# > Indented block

# %%
def build_index_ver1(rdd_data,location):
    word_counts = rdd_data.flatMap(lambda x: word_count(x[0], x[1]))
    postings = word_counts.groupByKey().mapValues(reduce_word_counts)

    w2df = calculate_df(postings)
    w2df_dict = w2df.collectAsMap()
    posting_locs_list = partition_postings_and_write(postings,location).collect()

    super_posting_locs = defaultdict(list)
    for posting_loc in posting_locs_list:
      for k, v in posting_loc.items():
        super_posting_locs[k].extend(v)

    # Create inverted index instance
    inverted = InvertedIndex()
    # Adding the posting locations dictionary to the inverted index
    inverted.posting_locs = super_posting_locs
    # Add the token - df dictionary to the inverted index
    inverted.df = w2df_dict
    # write the global stats out

    inverted.write_index(location, 'index')

    return inverted

#index_body=build_index_ver1(wiki_data_body,'./body_index')
# 
#index_title=build_index_ver1(wiki_data_title,'./title_index')

# %%
def word_count_anchor(id,list_of_tupels):
  ''' Count the frequency of each word in `text` (tf) that is not included in 
  `all_stopwords` and return entries that will go into our posting lists. 
  Parameters:
  -----------
    text: str
      Text of one document
    id: int
      Document id
  Returns:
  --------
    List of tuples
      A list of (token, (doc_id, tf)) pairs 
      for example: [("Anarchism", (12, 5)), ...]
  '''
  t=flatten_lst([RE_WORD.finditer(text.lower()) for dest_id,text in list_of_tupels])

  tokens = [token.group() for token in t]

  terms = {}
  tf = Counter()
  for token in tokens:
    if token in all_stopwords:
      continue
    current = tf.get(token, 0)
    tf[token] = current + 1
    terms[token] = (id,current +1)


  return list(terms.items())

def build_index_ver2(rdd_data,location):
    word_counts_body = rdd_data.flatMap(lambda x: word_count_anchor(x[0], x[1]))
    postings = word_counts_body.groupByKey().mapValues(reduce_word_counts)

    w2df = calculate_df(postings)

    w2df_dict = w2df.collectAsMap()
    posting_locs_list = partition_postings_and_write(postings,location).collect()

    super_posting_locs = defaultdict(list)
    for posting_loc in posting_locs_list:
      for k, v in posting_loc.items():
        super_posting_locs[k].extend(v)

    # Create inverted index instance
    inverted = InvertedIndex()
    # Adding the posting locations dictionary to the inverted index
    inverted.posting_locs = super_posting_locs
    # Add the token - df dictionary to the inverted index
    inverted.df = w2df_dict
    # write the global stats out
    inverted.write_index(location, 'index')

    return inverted


#index_anchor=build_index_ver2(wiki_data_anchor,'./anchor_index')

# %%
# Indexbuilding - Change to "True" to build index
if False:
  print("Creating indices folders")
  # !mkdir body_index title_index anchor_index
  print("Building body index.")
  index_body=build_index_ver1(wiki_data_body,'./body_index')
  print("Building body index done. Building title index.")
  index_title=build_index_ver1(wiki_data_title,'./title_index')
  print("Building title index done. Building anchor text index.")
  index_anchor=build_index_ver2(wiki_data_anchor,'./anchor_index')
  print("Building anchor text index done. Indexing completed.")
# Out:
# Creating indices folders
# Building body index.
# Building body index done. Building title index.
# Building title index done. Building anchor text index.
# Building anchor text index done. Indexing completed.

# %%
lst=[(1,2),(2,3),(2,4)]
d = Counter()

for t in lst:
  d[t[0]]+=t[1]

list(d.items())
# Out:
# [(1, 2), (2, 7)]

# %% [markdown]
# #queries actions

# %%
queries=[q for q,d in queries_to_docs_raw.items()]
q_tokenes_lst=[q.split() for q in queries]
all_terms=[item for sublist in q_tokenes_lst for item in sublist]
q_tokenes_dict={i:q for i,q in enumerate(q_tokenes_lst)}

# %% [markdown]
# # loading big index and DLs : <font color='green'>Indexes here</font>

# %%
from google.colab import drive
drive.mount('/content/drive')

drive_base_path='./drive/MyDrive/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# loading DLs

# %%
with open(drive_base_path+"title_index/"+'title_DL.json', 'rt') as f:
  title_DL = json.load(f)
with open(drive_base_path+"anchor_index/"+'anchor_DL.json', 'rt') as f:
  anchor_DL = json.load(f)
with open(drive_base_path+"body_index/"+'body_DL.json', 'rt') as f:
  body_DL = json.load(f)

# %% [markdown]
# loading indexes

# %%
title_index=InvertedIndex.read_index(drive_base_path+'title_index', 'index')
anchor_index=InvertedIndex.read_index(drive_base_path+'anchor_index', 'index')
body_index=InvertedIndex.read_index(drive_base_path+'body_index', 'index')

# !cp drive_base_path+'body_index'
# Out:
# cp: missing destination file operand after 'drive_base_path+body_index'
# Try 'cp --help' for more information.

# %% [markdown]
# Changing posting locs to match local colab file location

# %%
def change_index_locs(index):
    for term,loc_tuple in index.posting_locs.items():
      new_list = []
      for loc,offset in loc_tuple:
        splited = loc.split("/")
        for part in splited:
          if "index" in part:
            rebuilt = part
          if "bin" in part:
            rebuilt = "/content/drive/MyDrive/" + rebuilt + "/" + part
        loc_tuple = (rebuilt,offset)
        new_list.append(loc_tuple)
      index.posting_locs[term] = new_list
if True: #Change to "True" to enable
  change_index_locs(body_index)
  change_index_locs(anchor_index)
  change_index_locs(title_index)

# %%
  # lst=list(title_index.posting_locs.values())[0]

  # with closing(MultiFileReader()) as reader:
  #   res=reader.read(lst, BLOCK_SIZE)
  # res

def find_postings(terms,index):
    res={}
    with closing(MultiFileReader()) as reader:
        for w, locs in index.posting_locs.items():
          if(res.keys()==terms):
          #if (terms in res.keys()):
            break
          if(w not in terms):
            continue
          else:
            b = reader.read(locs, index.df[w] * TUPLE_SIZE)
            posting_list = []
            for i in range(index.df[w]):
              doc_id = int.from_bytes(b[i*TUPLE_SIZE:i*TUPLE_SIZE+4], 'big')
              tf = int.from_bytes(b[i*TUPLE_SIZE+4:(i+1)*TUPLE_SIZE], 'big')
              posting_list.append((doc_id, tf))
            res[w]=posting_list

    return res

# %%
def group_list_of_tuples(lst):
    d = Counter()

    for t in lst:
        d[t[0]]+=t[1]
    
    return d.items()

# %%
def tf_idf(t,d,DL,index,tf):
  term_freq_not_normelized=tf
  D=DL[str(d)]
  tf=term_freq_not_normelized/D
  N=len(DL)
  idf=math.log2(N/index.df[t])
  return tf*idf

# %%
def cosine_sim(index,DL,query,N = 3):
  dict_count = Counter()
  pls = find_postings(np.unique(query).tolist(),index)
  tf_q = Counter()
  d_tfs = defaultdict(list)
  for t in query:
    tf_q[t] += 1
  for t,pl in pls.items():
    for doc_id,tf_d in pl:
      tf_idf_val=tf_idf(t,doc_id,DL,index,tf_d)
      dict_count[doc_id] += (tf_q[t]) * tf_idf_val
      d_tfs[doc_id].append(tf_idf_val)
  for doc_id,value in dict_count.items():
    dict_count[doc_id] = value*(1/(norm(list(tf_q.values()))))*(1/(norm(list(d_tfs[doc_id]))))
  return sorted([(doc_id, builtins.round(score,5)) for doc_id, score in dict_count.items()], key = lambda x: x[1],reverse=True)[:N]

# %%
qid_to_true_docs_dict={i:d[1] for i,d in enumerate(queries_to_docs_raw.items())}
d = {}
queries = {i:[t.lower() for t in q_lst] for i,q_lst in q_tokenes_dict.items()}

for query in queries:
  d[query] = cosine_sim(index_body,body_DL,queries[query],40)

# %%
D={}
for query in queries:
  D[query] = cosine_sim(body_index,body_DL,queries[query],40)

# %% [markdown]
# # binary ranking using the title of articles and anchor text

# %%
def binary_ranking_for_anchor_text(query,index):
  words,pls=zip(*index.posting_lists_iter())
  matches = Counter()
  for term in np.unique(query): 
        if term.lower() in words:            
            list_of_doc = pls[words.index(term.lower())]    
            for doc_id, freq in list_of_doc:
                matches[doc_id] = matches.get(doc_id, 0) + 1
  return sorted(matches.items(),key=lambda x:x[1], reverse =True)

# %%
#Anchor text ranking
binary_ranking_for_anchor_text(q_tokenes_lst[0],index_title)

# %%
#Title text ranking
binary_ranking_for_anchor_text(q_tokenes_lst[1],anchor_index)

# %% [markdown]
# # ranking by PageRank

# %%
# Put your `generate_graph` function here
def generate_graph(pages):
  ''' Compute the directed graph generated by wiki links.
  Parameters:
  -----------
    pages: RDD
      An RDD where each row consists of one wikipedia articles with 'id' and 
      'anchor_text'.
  Returns:
  --------
    edges: RDD
      An RDD where each row represents an edge in the directed graph created by
      the wikipedia links. The first entry should the source page id and the 
      second entry is the destination page id. No duplicates should be present. 
    vertices: RDD
      An RDD where each row represents a vetrix (node) in the directed graph 
      created by the wikipedia links. No duplicates should be present. 
  '''
  # YOUR CODE HERE

  temp = pages.partitionBy(16) #partitioning for speed
  sc = SparkContext.getOrCreate(SparkConf().setMaster("local[*]"))
  edges = temp.flatMap(lambda x:[(x[0],each[0]) for each in x[1]]).distinct() ## might have dupli
  p1 = temp.flatMap(lambda x:[(each[0],) for each in x[1]])
  p2 = temp.map(lambda x:(x[0],))
  vert = p1.union(p2).distinct()
  return edges,vert

# %%
t_start = time()
#pages_links = spark.read.parquet("gs://wikidata_preprocessed/*").select("id", "anchor_text").rdd
# construct the graph 
edges, vertices = generate_graph(wiki_data_anchor)
# compute PageRank
edgesDF = edges.toDF(['src', 'dst']).repartition(124, 'src')
verticesDF = vertices.toDF(['id']).repartition(124, 'id')
g = GraphFrame(verticesDF, edgesDF)
pr_results = g.pageRank(resetProbability=0.15, maxIter=6)
pr = pr_results.vertices.select("id", "pagerank")
pr = pr.sort(col('pagerank').desc())
#pr.repartition(1).write.csv(f'gs://{bucket_name}/pr', compression="gzip")

# %%
df=pr.toPandas()
df_tup=df.to_records(index=False)
df_dict=defaultdict(list)
for tup in list(df_tup):
  key=tup[0]%800
  df_dict[int(key)].append((int(tup[0]),tup[1]))

# %%
# !mkdir prr

# %%
# list(df_tup)

for k,vals in df_dict.items():
  with open('prr/pr'+str(k)+'.json', 'w') as convert_file:
     convert_file.write(json.dumps(df_dict[k]))

# %%
def getPr(id):
  k=id%800
  with open('prr/pr'+str(k)+'.json', 'rt') as f:
     pr_k = json.load(f)
  for t in pr_k:
    if t[0]==id:
      return t[1]
  return 0

# %%
getPr(603770)
# Out:
# 0.9996098662189107

# %% [markdown]
# # ranking by article page views

# %%
# Paths
# Using user page views (as opposed to spiders and automated traffic) for the 
# month of August 2021
pv_path = 'https://dumps.wikimedia.org/other/pageview_complete/monthly/2021/2021-08/pageviews-202108-user.bz2'
p = Path(pv_path) 
pv_name = p.name
pv_temp = f'{p.stem}-4dedup.txt'
pv_clean = f'{p.stem}.pkl'
# Download the file (2.3GB) 
# !wget -N $pv_path
# Filter for English pages, and keep just two fields: article ID (3) and monthly 
# total number of page views (5). Then, remove lines with article id or page 
# view values that are not a sequence of digits.
# !bzcat $pv_name | grep "^en\.wikipedia" | cut -d' ' -f3,5 | grep -P "^\d+\s\d+$" > $pv_temp
# Create a Counter (dictionary) that sums up the pages views for the same 
# article, resulting in a mapping from article id to total page views.
wid2pv = Counter()
with open(pv_temp, 'rt') as f:
  for line in f:
    parts = line.split(' ')
    wid2pv.update({int(parts[0]): int(parts[1])})
# write out the counter as binary file (pickle it)
with open(pv_clean, 'wb') as f:
  pickle.dump(wid2pv, f)
# read in the counter
with open(pv_clean, 'rb') as f:
  wid2pv = pickle.loads(f.read())
# Out:
# --2022-01-05 15:02:08--  https://dumps.wikimedia.org/other/pageview_complete/monthly/2021/2021-08/pageviews-202108-user.bz2
# Resolving dumps.wikimedia.org (dumps.wikimedia.org)... 208.80.154.7, 2620:0:861:1:208:80:154:7
# Connecting to dumps.wikimedia.org (dumps.wikimedia.org)|208.80.154.7|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2503235912 (2.3G) [application/octet-stream]
# Saving to: ‘pageviews-202108-user.bz2’
#
# pageviews-202108-us 100%[===================>]   2.33G  4.68MB/s    in 8m 33s
#
# 2022-01-05 15:10:41 (4.66 MB/s) - ‘pageviews-202108-user.bz2’ saved [2503235912/2503235912]

# %%
# !mkdir pv

# %%
pv_dict=defaultdict(list)
for id,pv in wid2pv.items():
  key=id%800
  pv_dict[int(key)].append((int(id),pv))

# %%
for k,vals in df_dict.items():
  with open('pv/pv'+str(k)+'.json', 'w') as convert_file:
     convert_file.write(json.dumps(pv_dict[k]))

# %%
def getPv(id):
  k=id%800
  with open('pv/pv'+str(k)+'.json', 'rt') as f:
     pr_k = json.load(f)
  for t in pr_k:
    if t[0]==id:
      return t[1]
  return 0

# %%
getPv(603770)
# Out:
# 2403

# %%
# !gsutil cp -r pv gs://ir-project-harel-and-saar

# %%
# !gsutil cp -r pv drive/MyDrive
# Out:
# Copying file://pv/pv164.json...
# Copying file://pv/pv344.json...
# Copying file://pv/pv399.json...
# Copying file://pv/pv541.json...
# / [4 files][822.1 KiB/822.1 KiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying file://pv/pv295.json...
# Copying file://pv/pv775.json...
# Copying file://pv/pv280.json...
# Copying file://pv/pv502.json...
# Copying file://pv/pv608.json...
# Copying file://pv/pv244.json...
# Copying file://pv/pv375.json...
# Copying file://pv/pv591.json...
# Copying file://pv/pv412.json...
# Copying file://pv/pv171.json...
# Copying file://pv/pv699.json...
# Copying file://pv/pv215.json...
# Copying file://pv/pv525.json...
# Copying file://pv/pv94.json...
# Copying file://pv/pv336.json...
# Copying file://pv/pv651.json...
# Copying file://pv/pv3.json...
# Copying file://pv/pv79.json...
# Copying file://pv/pv730.json...
# Copying file://pv/pv10.json...
# Copying file://pv/pv105.json...
# Copying file://pv/pv148.json...
# Copying file://pv/pv773.json...
# Copying file://pv/pv739.json...
# Copying file://pv/pv149.json...
# Copying file://pv/pv253.json...
# Copying file://pv/pv535.json...
# Copying file://pv/pv137.json...
# Copying file://pv/pv648.json...
# Copying file://pv/pv57.json...
# Copying file://pv/pv89.json...
# Copying file://pv/pv721.json...
# Copying file://pv/pv574.json...
# Copying file://pv/pv117.json...
# Copying file://pv/pv372.json...
# Copying file://pv/pv46.json...
# Copying file://pv/pv565.json...
# Copying file://pv/pv320.json...
# Copying file://pv/pv56.json...
# Copying file://pv/pv48.json...
# Copying file://pv/pv685.json...
# Copying file://pv/pv432.json...
# Copying file://pv/pv493.json...
# Copying file://pv/pv386.json...
# Copying file://pv/pv299.json...
# Copying file://pv/pv446.json...
# Copying file://pv/pv626.json...
# Copying file://pv/pv238.json...
# Copying file://pv/pv278.json...
# Copying file://pv/pv356.json...
# Copying file://pv/pv262.json...
# Copying file://pv/pv260.json...
# Copying file://pv/pv750.json...
# Copying file://pv/pv478.json...
# Copying file://pv/pv655.json...
# Copying file://pv/pv785.json...
# Copying file://pv/pv407.json...
# Copying file://pv/pv85.json...
# Copying file://pv/pv632.json...
# Copying file://pv/pv156.json...
# Copying file://pv/pv462.json...
# Copying file://pv/pv443.json...
# Copying file://pv/pv62.json...
# Copying file://pv/pv766.json...
# Copying file://pv/pv416.json...
# Copying file://pv/pv611.json...
# Copying file://pv/pv503.json...
# Copying file://pv/pv211.json...
# Copying file://pv/pv745.json...
# Copying file://pv/pv596.json...
# Copying file://pv/pv118.json...
# Copying file://pv/pv18.json...
# Copying file://pv/pv455.json...
# Copying file://pv/pv638.json...
# Copying file://pv/pv580.json...
# Copying file://pv/pv710.json...
# Copying file://pv/pv86.json...
# Copying file://pv/pv34.json...
# Copying file://pv/pv494.json...
# Copying file://pv/pv687.json...
# Copying file://pv/pv549.json...
# Copying file://pv/pv231.json...
# Copying file://pv/pv545.json...
# Copying file://pv/pv248.json...
# Copying file://pv/pv234.json...
# Copying file://pv/pv658.json...
# Copying file://pv/pv480.json...
# Copying file://pv/pv294.json...
# Copying file://pv/pv538.json...
# Copying file://pv/pv729.json...
# Copying file://pv/pv132.json...
# Copying file://pv/pv206.json...
# Copying file://pv/pv291.json...
# Copying file://pv/pv439.json...
# Copying file://pv/pv122.json...
# Copying file://pv/pv415.json...
# Copying file://pv/pv558.json...
# Copying file://pv/pv49.json...
# Copying file://pv/pv300.json...
# Copying file://pv/pv665.json...
# Copying file://pv/pv83.json...
# Copying file://pv/pv104.json...
# Copying file://pv/pv445.json...
# Copying file://pv/pv705.json...
# Copying file://pv/pv467.json...
# Copying file://pv/pv696.json...
# Copying file://pv/pv776.json...
# Copying file://pv/pv161.json...
# Copying file://pv/pv263.json...
# Copying file://pv/pv543.json...
# Copying file://pv/pv509.json...
# Copying file://pv/pv703.json...
# Copying file://pv/pv524.json...
# Copying file://pv/pv662.json...
# Copying file://pv/pv748.json...
# Copying file://pv/pv409.json...
# Copying file://pv/pv227.json...
# Copying file://pv/pv780.json...
# Copying file://pv/pv689.json...
# Copying file://pv/pv637.json...
# Copying file://pv/pv627.json...
# Copying file://pv/pv500.json...
# Copying file://pv/pv241.json...
# Copying file://pv/pv345.json...
# Copying file://pv/pv367.json...
# Copying file://pv/pv235.json...
# Copying file://pv/pv323.json...
# Copying file://pv/pv24.json...
# Copying file://pv/pv37.json...
# Copying file://pv/pv677.json...
# Copying file://pv/pv360.json...
# Copying file://pv/pv614.json...
# Copying file://pv/pv259.json...
# Copying file://pv/pv38.json...
# Copying file://pv/pv454.json...
# Copying file://pv/pv760.json...
# Copying file://pv/pv33.json...
# Copying file://pv/pv575.json...
# Copying file://pv/pv695.json...
# Copying file://pv/pv306.json...
# Copying file://pv/pv365.json...
# Copying file://pv/pv158.json...
# Copying file://pv/pv8.json...
# Copying file://pv/pv186.json...
# Copying file://pv/pv708.json...
# Copying file://pv/pv561.json...
# Copying file://pv/pv176.json...
# Copying file://pv/pv368.json...
# Copying file://pv/pv277.json...
# Copying file://pv/pv754.json...
# Copying file://pv/pv765.json...
# Copying file://pv/pv633.json...
# Copying file://pv/pv516.json...
# Copying file://pv/pv339.json...
# Copying file://pv/pv303.json...
# Copying file://pv/pv628.json...
# Copying file://pv/pv764.json...
# Copying file://pv/pv230.json...
# Copying file://pv/pv119.json...
# Copying file://pv/pv514.json...
# Copying file://pv/pv185.json...
# Copying file://pv/pv797.json...
# Copying file://pv/pv334.json...
# Copying file://pv/pv153.json...
# Copying file://pv/pv258.json...
# Copying file://pv/pv163.json...
# Copying file://pv/pv133.json...
# Copying file://pv/pv120.json...
# Copying file://pv/pv470.json...
# Copying file://pv/pv798.json...
# Copying file://pv/pv239.json...
# Copying file://pv/pv450.json...
# Copying file://pv/pv661.json...
# Copying file://pv/pv457.json...
# Copying file://pv/pv693.json...
# Copying file://pv/pv364.json...
# Copying file://pv/pv274.json...
# Copying file://pv/pv418.json...
# Copying file://pv/pv630.json...
# Copying file://pv/pv195.json...
# Copying file://pv/pv743.json...
# Copying file://pv/pv25.json...
# Copying file://pv/pv52.json...
# Copying file://pv/pv550.json...
# Copying file://pv/pv219.json...
# Copying file://pv/pv425.json...
# Copying file://pv/pv779.json...
# Copying file://pv/pv168.json...
# Copying file://pv/pv125.json...
# Copying file://pv/pv641.json...
# Copying file://pv/pv99.json...
# Copying file://pv/pv488.json...
# Copying file://pv/pv236.json...
# Copying file://pv/pv135.json...
# Copying file://pv/pv485.json...
# Copying file://pv/pv26.json...
# Copying file://pv/pv473.json...
# Copying file://pv/pv472.json...
# Copying file://pv/pv166.json...
# Copying file://pv/pv287.json...
# Copying file://pv/pv84.json...
# Copying file://pv/pv114.json...
# Copying file://pv/pv93.json...
# Copying file://pv/pv242.json...
# Copying file://pv/pv335.json...
# Copying file://pv/pv747.json...
# Copying file://pv/pv609.json...
# Copying file://pv/pv374.json...
# Copying file://pv/pv106.json...
# Copying file://pv/pv555.json...
# Copying file://pv/pv255.json...
# Copying file://pv/pv151.json...
# Copying file://pv/pv72.json...
# Copying file://pv/pv377.json...
# Copying file://pv/pv437.json...
# Copying file://pv/pv279.json...
# Copying file://pv/pv456.json...
# Copying file://pv/pv759.json...
# Copying file://pv/pv15.json...
# Copying file://pv/pv362.json...
# Copying file://pv/pv333.json...
# Copying file://pv/pv65.json...
# Copying file://pv/pv594.json...
# Copying file://pv/pv378.json...
# Copying file://pv/pv382.json...
# Copying file://pv/pv617.json...
# Copying file://pv/pv359.json...
# Copying file://pv/pv297.json...
# Copying file://pv/pv681.json...
# Copying file://pv/pv452.json...
# Copying file://pv/pv421.json...
# Copying file://pv/pv102.json...
# Copying file://pv/pv670.json...
# Copying file://pv/pv353.json...
# Copying file://pv/pv61.json...
# Copying file://pv/pv209.json...
# Copying file://pv/pv518.json...
# Copying file://pv/pv527.json...
# Copying file://pv/pv190.json...
# Copying file://pv/pv405.json...
# Copying file://pv/pv63.json...
# Copying file://pv/pv281.json...
# Copying file://pv/pv87.json...
# Copying file://pv/pv305.json...
# Copying file://pv/pv504.json...
# Copying file://pv/pv576.json...
# Copying file://pv/pv39.json...
# Copying file://pv/pv43.json...
# Copying file://pv/pv75.json...
# Copying file://pv/pv392.json...
# Copying file://pv/pv712.json...
# Copying file://pv/pv201.json...
# Copying file://pv/pv461.json...
# Copying file://pv/pv298.json...
# Copying file://pv/pv725.json...
# Copying file://pv/pv379.json...
# Copying file://pv/pv544.json...
# Copying file://pv/pv463.json...
# Copying file://pv/pv690.json...
# Copying file://pv/pv17.json...
# Copying file://pv/pv110.json...
# Copying file://pv/pv592.json...
# Copying file://pv/pv66.json...
# Copying file://pv/pv572.json...
# Copying file://pv/pv381.json...
# Copying file://pv/pv165.json...
# Copying file://pv/pv684.json...
# Copying file://pv/pv613.json...
# Copying file://pv/pv324.json...
# Copying file://pv/pv32.json...
# Copying file://pv/pv70.json...
# Copying file://pv/pv583.json...
# Copying file://pv/pv214.json...
# Copying file://pv/pv210.json...
# Copying file://pv/pv490.json...
# Copying file://pv/pv307.json...
# Copying file://pv/pv391.json...
# Copying file://pv/pv0.json...
# Copying file://pv/pv189.json...
# Copying file://pv/pv30.json...
# Copying file://pv/pv273.json...
# Copying file://pv/pv680.json...
# Copying file://pv/pv599.json...
# Copying file://pv/pv396.json...
# Copying file://pv/pv58.json...
# Copying file://pv/pv36.json...
# Copying file://pv/pv466.json...
# Copying file://pv/pv683.json...
# Copying file://pv/pv395.json...
# Copying file://pv/pv142.json...
# Copying file://pv/pv788.json...
# Copying file://pv/pv417.json...
# Copying file://pv/pv245.json...
# Copying file://pv/pv139.json...
# Copying file://pv/pv202.json...
# Copying file://pv/pv13.json...
# Copying file://pv/pv5.json...
# Copying file://pv/pv249.json...
# Copying file://pv/pv701.json...
# Copying file://pv/pv513.json...
# Copying file://pv/pv477.json...
# Copying file://pv/pv706.json...
# Copying file://pv/pv212.json...
# Copying file://pv/pv646.json...
# Copying file://pv/pv369.json...
# Copying file://pv/pv256.json...
# Copying file://pv/pv20.json...
# Copying file://pv/pv223.json...
# Copying file://pv/pv465.json...
# Copying file://pv/pv521.json...
# Copying file://pv/pv343.json...
# Copying file://pv/pv794.json...
# Copying file://pv/pv283.json...
# Copying file://pv/pv652.json...
# Copying file://pv/pv448.json...
# Copying file://pv/pv568.json...
# Copying file://pv/pv688.json...
# Copying file://pv/pv338.json...
# Copying file://pv/pv741.json...
# Copying file://pv/pv474.json...
# Copying file://pv/pv792.json...
# Copying file://pv/pv183.json...
# Copying file://pv/pv78.json...
# Copying file://pv/pv53.json...
# Copying file://pv/pv422.json...
# Copying file://pv/pv82.json...
# Copying file://pv/pv722.json...
# Copying file://pv/pv719.json...
# Copying file://pv/pv216.json...
# Copying file://pv/pv460.json...
# Copying file://pv/pv246.json...
# Copying file://pv/pv47.json...
# Copying file://pv/pv469.json...
# Copying file://pv/pv366.json...
# Copying file://pv/pv522.json...
# Copying file://pv/pv252.json...
# Copying file://pv/pv363.json...
# Copying file://pv/pv496.json...
# Copying file://pv/pv468.json...
# Copying file://pv/pv347.json...
# Copying file://pv/pv770.json...
# Copying file://pv/pv790.json...
# Copying file://pv/pv624.json...
# Copying file://pv/pv557.json...
# Copying file://pv/pv341.json...
# Copying file://pv/pv744.json...
# Copying file://pv/pv69.json...
# Copying file://pv/pv160.json...
# Copying file://pv/pv218.json...
# Copying file://pv/pv197.json...
# Copying file://pv/pv489.json...
# Copying file://pv/pv508.json...
# Copying file://pv/pv715.json...
# Copying file://pv/pv742.json...
# Copying file://pv/pv716.json...
# Copying file://pv/pv267.json...
# Copying file://pv/pv116.json...
# Copying file://pv/pv243.json...
# Copying file://pv/pv511.json...
# Copying file://pv/pv265.json...
# Copying file://pv/pv612.json...
# Copying file://pv/pv144.json...
# Copying file://pv/pv634.json...
# Copying file://pv/pv351.json...
# Copying file://pv/pv486.json...
# Copying file://pv/pv51.json...
# Copying file://pv/pv221.json...
# Copying file://pv/pv539.json...
# Copying file://pv/pv589.json...
# Copying file://pv/pv55.json...
# Copying file://pv/pv182.json...
# Copying file://pv/pv254.json...
# Copying file://pv/pv731.json...
# Copying file://pv/pv329.json...
# Copying file://pv/pv330.json...
# Copying file://pv/pv547.json...
# Copying file://pv/pv203.json...
# Copying file://pv/pv498.json...
# Copying file://pv/pv479.json...
# Copying file://pv/pv384.json...
# Copying file://pv/pv727.json...
# Copying file://pv/pv6.json...
# Copying file://pv/pv571.json...
# Copying file://pv/pv357.json...
# Copying file://pv/pv237.json...
# Copying file://pv/pv447.json...
# Copying file://pv/pv679.json...
# Copying file://pv/pv88.json...
# Copying file://pv/pv194.json...
# Copying file://pv/pv346.json...
# Copying file://pv/pv169.json...
# Copying file://pv/pv436.json...
# Copying file://pv/pv131.json...
# Copying file://pv/pv96.json...
# Copying file://pv/pv642.json...
# Copying file://pv/pv713.json...
# Copying file://pv/pv605.json...
# Copying file://pv/pv250.json...
# Copying file://pv/pv327.json...
# Copying file://pv/pv723.json...
# Copying file://pv/pv618.json...
# Copying file://pv/pv564.json...
# Copying file://pv/pv266.json...
# Copying file://pv/pv286.json...
# Copying file://pv/pv77.json...
# Copying file://pv/pv7.json...
# Copying file://pv/pv179.json...
# Copying file://pv/pv664.json...
# Copying file://pv/pv718.json...
# Copying file://pv/pv536.json...
# Copying file://pv/pv669.json...
# Copying file://pv/pv623.json...
# Copying file://pv/pv600.json...
# Copying file://pv/pv615.json...
# Copying file://pv/pv757.json...
# Copying file://pv/pv440.json...
# Copying file://pv/pv204.json...
# Copying file://pv/pv528.json...
# Copying file://pv/pv383.json...
# Copying file://pv/pv573.json...
# Copying file://pv/pv644.json...
# Copying file://pv/pv411.json...
# Copying file://pv/pv736.json...
# Copying file://pv/pv74.json...
# Copying file://pv/pv402.json...
# Copying file://pv/pv563.json...
# Copying file://pv/pv371.json...
# Copying file://pv/pv91.json...
# Copying file://pv/pv548.json...
# Copying file://pv/pv319.json...
# Copying file://pv/pv507.json...
# Copying file://pv/pv595.json...
# Copying file://pv/pv526.json...
# Copying file://pv/pv340.json...
# Copying file://pv/pv282.json...
# Copying file://pv/pv220.json...
# Copying file://pv/pv678.json...
# Copying file://pv/pv97.json...
# Copying file://pv/pv483.json...
# Copying file://pv/pv264.json...
# Copying file://pv/pv401.json...
# Copying file://pv/pv639.json...
# Copying file://pv/pv497.json...
# Copying file://pv/pv767.json...
# Copying file://pv/pv136.json...
# Copying file://pv/pv193.json...
# Copying file://pv/pv40.json...
# Copying file://pv/pv226.json...
# Copying file://pv/pv471.json...
# Copying file://pv/pv134.json...
# Copying file://pv/pv376.json...
# Copying file://pv/pv59.json...
# Copying file://pv/pv54.json...
# Copying file://pv/pv296.json...
# Copying file://pv/pv229.json...
# Copying file://pv/pv675.json...
# Copying file://pv/pv12.json...
# Copying file://pv/pv654.json...
# Copying file://pv/pv80.json...
# Copying file://pv/pv650.json...
# Copying file://pv/pv410.json...
# Copying file://pv/pv325.json...
# Copying file://pv/pv784.json...
# Copying file://pv/pv660.json...
# Copying file://pv/pv155.json...
# Copying file://pv/pv304.json...
# Copying file://pv/pv603.json...
# Copying file://pv/pv358.json...
# Copying file://pv/pv749.json...
# Copying file://pv/pv101.json...
# Copying file://pv/pv200.json...
# Copying file://pv/pv318.json...
# Copying file://pv/pv313.json...
# Copying file://pv/pv173.json...
# Copying file://pv/pv11.json...
# Copying file://pv/pv21.json...
# Copying file://pv/pv601.json...
# Copying file://pv/pv570.json...
# Copying file://pv/pv487.json...
# Copying file://pv/pv542.json...
# Copying file://pv/pv261.json...
# Copying file://pv/pv590.json...
# Copying file://pv/pv442.json...
# Copying file://pv/pv27.json...
# Copying file://pv/pv512.json...
# Copying file://pv/pv420.json...
# Copying file://pv/pv582.json...
# Copying file://pv/pv430.json...
# Copying file://pv/pv796.json...
# Copying file://pv/pv380.json...
# Copying file://pv/pv172.json...
# Copying file://pv/pv532.json...
# Copying file://pv/pv726.json...
# Copying file://pv/pv464.json...
# Copying file://pv/pv738.json...
# Copying file://pv/pv734.json...
# Copying file://pv/pv753.json...
# Copying file://pv/pv427.json...
# Copying file://pv/pv207.json...
# Copying file://pv/pv732.json...
# Copying file://pv/pv29.json...
# Copying file://pv/pv228.json...
# Copying file://pv/pv520.json...
# Copying file://pv/pv126.json...
# Copying file://pv/pv191.json...
# Copying file://pv/pv682.json...
# Copying file://pv/pv373.json...
# Copying file://pv/pv529.json...
# Copying file://pv/pv694.json...
# Copying file://pv/pv787.json...
# Copying file://pv/pv795.json...
# Copying file://pv/pv317.json...
# Copying file://pv/pv257.json...
# Copying file://pv/pv170.json...
# Copying file://pv/pv668.json...
# Copying file://pv/pv616.json...
# Copying file://pv/pv331.json...
# Copying file://pv/pv9.json...
# Copying file://pv/pv397.json...
# Copying file://pv/pv31.json...
# Copying file://pv/pv534.json...
# Copying file://pv/pv737.json...
# Copying file://pv/pv167.json...
# Copying file://pv/pv394.json...
# Copying file://pv/pv112.json...
# Copying file://pv/pv789.json...
# Copying file://pv/pv546.json...
# Copying file://pv/pv308.json...
# Copying file://pv/pv198.json...
# Copying file://pv/pv569.json...
# Copying file://pv/pv408.json...
# Copying file://pv/pv482.json...
# Copying file://pv/pv426.json...
# Copying file://pv/pv95.json...
# Copying file://pv/pv98.json...
# Copying file://pv/pv41.json...
# Copying file://pv/pv233.json...
# Copying file://pv/pv783.json...
# Copying file://pv/pv610.json...
# Copying file://pv/pv175.json...
# Copying file://pv/pv390.json...
# Copying file://pv/pv431.json...
# Copying file://pv/pv505.json...
# Copying file://pv/pv2.json...
# Copying file://pv/pv444.json...
# Copying file://pv/pv621.json...
# Copying file://pv/pv588.json...
# Copying file://pv/pv686.json...
# Copying file://pv/pv554.json...
# Copying file://pv/pv247.json...
# Copying file://pv/pv128.json...
# Copying file://pv/pv270.json...
# Copying file://pv/pv130.json...
# Copying file://pv/pv556.json...
# Copying file://pv/pv127.json...
# Copying file://pv/pv577.json...
# Copying file://pv/pv709.json...
# Copying file://pv/pv217.json...
# Copying file://pv/pv387.json...
# Copying file://pv/pv141.json...
# Copying file://pv/pv400.json...
# Copying file://pv/pv484.json...
# Copying file://pv/pv774.json...
# Copying file://pv/pv222.json...
# Copying file://pv/pv475.json...
# Copying file://pv/pv620.json...
# Copying file://pv/pv309.json...
# Copying file://pv/pv174.json...
# Copying file://pv/pv622.json...
# Copying file://pv/pv778.json...
# Copying file://pv/pv756.json...
# Copying file://pv/pv393.json...
# Copying file://pv/pv292.json...
# Copying file://pv/pv676.json...
# Copying file://pv/pv606.json...
# Copying file://pv/pv45.json...
# Copying file://pv/pv673.json...
# Copying file://pv/pv510.json...
# Copying file://pv/pv523.json...
# Copying file://pv/pv337.json...
# Copying file://pv/pv150.json...
# Copying file://pv/pv100.json...
# Copying file://pv/pv208.json...
# Copying file://pv/pv428.json...
# Copying file://pv/pv640.json...
# Copying file://pv/pv269.json...
# Copying file://pv/pv598.json...
# Copying file://pv/pv348.json...
# Copying file://pv/pv631.json...
# Copying file://pv/pv453.json...
# Copying file://pv/pv349.json...
# Copying file://pv/pv272.json...
# Copying file://pv/pv140.json...
# Copying file://pv/pv714.json...
# Copying file://pv/pv354.json...
# Copying file://pv/pv559.json...
# Copying file://pv/pv310.json...
# Copying file://pv/pv581.json...
# Copying file://pv/pv584.json...
# Copying file://pv/pv103.json...
# Copying file://pv/pv321.json...
# Copying file://pv/pv1.json...
# Copying file://pv/pv108.json...
# Copying file://pv/pv697.json...
# Copying file://pv/pv552.json...
# Copying file://pv/pv653.json...
# Copying file://pv/pv438.json...
# Copying file://pv/pv553.json...
# Copying file://pv/pv180.json...
# Copying file://pv/pv92.json...
# Copying file://pv/pv44.json...
# Copying file://pv/pv711.json...
# Copying file://pv/pv60.json...
# Copying file://pv/pv213.json...
# Copying file://pv/pv332.json...
# Copying file://pv/pv433.json...
# Copying file://pv/pv763.json...
# Copying file://pv/pv501.json...
# Copying file://pv/pv530.json...
# Copying file://pv/pv224.json...
# Copying file://pv/pv276.json...
# Copying file://pv/pv90.json...
# Copying file://pv/pv424.json...
# Copying file://pv/pv414.json...
# Copying file://pv/pv636.json...
# Copying file://pv/pv143.json...
# Copying file://pv/pv71.json...
# Copying file://pv/pv587.json...
# Copying file://pv/pv717.json...
# Copying file://pv/pv326.json...
# Copying file://pv/pv619.json...
# Copying file://pv/pv28.json...
# Copying file://pv/pv746.json...
# Copying file://pv/pv398.json...
# Copying file://pv/pv459.json...
# Copying file://pv/pv597.json...
# Copying file://pv/pv285.json...
# Copying file://pv/pv602.json...
# Copying file://pv/pv178.json...
# Copying file://pv/pv656.json...
# Copying file://pv/pv607.json...
# Copying file://pv/pv312.json...
# Copying file://pv/pv413.json...
# Copying file://pv/pv506.json...
# Copying file://pv/pv107.json...
# Copying file://pv/pv177.json...
# Copying file://pv/pv289.json...
# Copying file://pv/pv64.json...
# Copying file://pv/pv781.json...
# Copying file://pv/pv451.json...
# Copying file://pv/pv316.json...
# Copying file://pv/pv225.json...
# Copying file://pv/pv293.json...
# Copying file://pv/pv406.json...
# Copying file://pv/pv740.json...
# Copying file://pv/pv35.json...
# Copying file://pv/pv566.json...
# Copying file://pv/pv284.json...
# Copying file://pv/pv302.json...
# Copying file://pv/pv50.json...
# Copying file://pv/pv196.json...
# Copying file://pv/pv129.json...
# Copying file://pv/pv649.json...
# Copying file://pv/pv560.json...
# Copying file://pv/pv629.json...
# Copying file://pv/pv519.json...
# Copying file://pv/pv19.json...
# Copying file://pv/pv268.json...
# Copying file://pv/pv311.json...
# Copying file://pv/pv733.json...
# Copying file://pv/pv314.json...
# Copying file://pv/pv700.json...
# Copying file://pv/pv667.json...
# Copying file://pv/pv458.json...
# Copying file://pv/pv423.json...
# Copying file://pv/pv315.json...
# Copying file://pv/pv146.json...
# Copying file://pv/pv192.json...
# Copying file://pv/pv551.json...
# Copying file://pv/pv793.json...
# Copying file://pv/pv791.json...
# Copying file://pv/pv562.json...
# Copying file://pv/pv361.json...
# Copying file://pv/pv702.json...
# Copying file://pv/pv403.json...
# Copying file://pv/pv113.json...
# Copying file://pv/pv352.json...
# Copying file://pv/pv647.json...
# Copying file://pv/pv355.json...
# Copying file://pv/pv109.json...
# Copying file://pv/pv799.json...
# Copying file://pv/pv782.json...
# Copying file://pv/pv121.json...
# Copying file://pv/pv159.json...
# Copying file://pv/pv275.json...
# Copying file://pv/pv181.json...
# Copying file://pv/pv16.json...
# Copying file://pv/pv635.json...
# Copying file://pv/pv752.json...
# Copying file://pv/pv350.json...
# Copying file://pv/pv720.json...
# Copying file://pv/pv704.json...
# Copying file://pv/pv663.json...
# Copying file://pv/pv404.json...
# Copying file://pv/pv643.json...
# Copying file://pv/pv14.json...
# Copying file://pv/pv188.json...
# Copying file://pv/pv251.json...
# Copying file://pv/pv578.json...
# Copying file://pv/pv769.json...
# Copying file://pv/pv240.json...
# Copying file://pv/pv152.json...
# Copying file://pv/pv645.json...
# Copying file://pv/pv389.json...
# Copying file://pv/pv199.json...
# Copying file://pv/pv162.json...
# Copying file://pv/pv657.json...
# Copying file://pv/pv604.json...
# Copying file://pv/pv728.json...
# Copying file://pv/pv322.json...
# Copying file://pv/pv123.json...
# Copying file://pv/pv691.json...
# Copying file://pv/pv533.json...
# Copying file://pv/pv81.json...
# Copying file://pv/pv674.json...
# Copying file://pv/pv157.json...
# Copying file://pv/pv441.json...
# Copying file://pv/pv707.json...
# Copying file://pv/pv232.json...
# Copying file://pv/pv758.json...
# Copying file://pv/pv73.json...
# Copying file://pv/pv537.json...
# Copying file://pv/pv435.json...
# Copying file://pv/pv429.json...
# Copying file://pv/pv205.json...
# Copying file://pv/pv187.json...
# Copying file://pv/pv481.json...
# Copying file://pv/pv625.json...
# Copying file://pv/pv271.json...
# Copying file://pv/pv762.json...
# Copying file://pv/pv579.json...
# Copying file://pv/pv751.json...
# Copying file://pv/pv419.json...
# Copying file://pv/pv492.json...
# Copying file://pv/pv138.json...
# Copying file://pv/pv288.json...
# Copying file://pv/pv672.json...
# Copying file://pv/pv671.json...
# Copying file://pv/pv184.json...
# Copying file://pv/pv4.json...
# Copying file://pv/pv786.json...
# Copying file://pv/pv342.json...
# Copying file://pv/pv771.json...
# Copying file://pv/pv385.json...
# Copying file://pv/pv515.json...
# Copying file://pv/pv772.json...
# Copying file://pv/pv124.json...
# Copying file://pv/pv692.json...
# Copying file://pv/pv154.json...
# Copying file://pv/pv517.json...
# Copying file://pv/pv593.json...
# Copying file://pv/pv328.json...
# Copying file://pv/pv585.json...
# Copying file://pv/pv147.json...
# Copying file://pv/pv23.json...
# Copying file://pv/pv735.json...
# Copying file://pv/pv67.json...
# Copying file://pv/pv22.json...
# Copying file://pv/pv755.json...
# Copying file://pv/pv724.json...
# Copying file://pv/pv768.json...
# Copying file://pv/pv659.json...
# Copying file://pv/pv761.json...
# Copying file://pv/pv495.json...
# Copying file://pv/pv586.json...
# Copying file://pv/pv434.json...
# Copying file://pv/pv370.json...
# Copying file://pv/pv698.json...
# Copying file://pv/pv290.json...
# Copying file://pv/pv76.json...
# Copying file://pv/pv666.json...
# Copying file://pv/pv567.json...
# Copying file://pv/pv777.json...
# Copying file://pv/pv115.json...
# Copying file://pv/pv491.json...
# Copying file://pv/pv145.json...
# Copying file://pv/pv301.json...
# Copying file://pv/pv531.json...
# Copying file://pv/pv540.json...
# Copying file://pv/pv68.json...
# Copying file://pv/pv388.json...
# Copying file://pv/pv111.json...
# Copying file://pv/pv499.json...
# Copying file://pv/pv449.json...
# Copying file://pv/pv476.json...
# Copying file://pv/pv42.json...
# \ [800 files][160.5 MiB/160.5 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 800 objects/160.5 MiB.

# %% [markdown]
# #getting top n with bm25

# %%
def get_candidate_documents(query_to_search,index,pls):
    """
    Generate a dictionary representing a pool of candidate documents for a given query. 
    
    Parameters:
    -----------
    query_to_search: list of tokens (str). This list will be preprocessed in advance (e.g., lower case, filtering stopwords, etc.'). 
                     Example: 'Hello, I love information retrival' --->  ['hello','love','information','retrieval']

    index:           inverted index loaded from the corresponding files.

    words,pls: generator for working with posting.
    Returns:
    -----------
    list of candidates. In the following format:
                                                               key: pair (doc_id,term)
                                                               value: tfidf score. 
    """
    #pls = find_postings(np.unique(query_to_search),index)
    candidates = []    
    for term,pl in pls.items():
        if term in index.df.keys():        
            current_list = pls[term.lower()]    
            candidates += current_list  

    return np.unique([d for d,s in candidates])

# %%
import math
from itertools import chain
import time
# When preprocessing the data have a dictionary of document length for each document saved in a variable called `DL`.
class BM25_from_index:
    """
    Best Match 25.    
    ----------
    k1 : float, default 1.5

    b : float, default 0.75

    index: inverted index
    """

    def __init__(self,index,DL,k1=1.5, b=0.75):
        self.b = b
        self.k1 = k1
        self.index = index
        self.N = len(DL)
        self.AVGDL = builtins.sum(DL.values())/self.N
        self.DL = DL
        #self.words, self.pls = zip(*self.index.posting_lists_iter())  

    def calc_idf(self,list_of_tokens):
        """
        This function calculate the idf values according to the BM25 idf formula for each term in the query.
        
        Parameters:
        -----------
        query: list of token representing the query. For example: ['look', 'blue', 'sky']
        
        Returns:
        -----------
        idf: dictionary of idf scores. As follows: 
                                                    key: term
                                                    value: bm25 idf score
        """        
        idf = {}        
        for term in list_of_tokens:            
            if term in self.index.df.keys():
                n_ti = self.index.df[term]
                idf[term] = math.log(1 + (self.N - n_ti + 0.5) / (n_ti + 0.5))
            else:
                pass                             
        return idf
        

    def search(self, queries,N=3):
        """
        This function calculate the bm25 score for given query and document.
        We need to check only documents which are 'candidates' for a given query. 
        This function return a dictionary of scores as the following:
                                                                    key: query_id
                                                                    value: a ranked list of pairs (doc_id, score) in the length of N.
        
        Parameters:
        -----------
        query: list of token representing the query. For example: ['look', 'blue', 'sky']
        doc_id: integer, document id.
        
        Returns:
        -----------
        score: float, bm25 score.
        """
        # YOUR CODE HERE
        terms = []
        for query in queries:
          for term in query:
            terms.append(term)
        uniques = set(terms)
        self.idf = self.calc_idf(uniques)

        output = OrderedDict()
        for i,query in enumerate(queries):
            scores = []
            #loading pls for the specific query's terms
            pls = find_postings(np.unique(query).tolist(),self.index)
            #candidates = get_candidate_documents(query,self.index,self.words,self.pls)
            candidates = get_candidate_documents(query,self.index,pls)

            #scores.append([(doc_id,builtins.round(self._score(query, doc_id,pls),3)) for doc_id in (([i for i in candidates]))])
            #for doc_id in (([i for i in candidates])):
            #  scores.append([(doc_id,builtins.round(self._score(query, doc_id,pls),3))
            #docs = [doc_id in (([i for i in candidates]))]:
            scores = list(self._score(query, candidates,pls).items())
            #scores = scores[0]
            scores.sort(reverse = True,key = lambda x:x[1])
            output[i] = scores[:N]

        return output

    def _score(self, query, docs,pls):
        """
        This function calculate the bm25 score for given query and document.
        
        Parameters:
        -----------
        query: list of token representing the query. For example: ['look', 'blue', 'sky']
        doc_id: integer, document id.
        
        Returns:
        -----------
        score: float, bm25 score.
        """        
        scores = Counter() #??
        #doc_len = self.DL[str(doc_id)]        
             
        # for term in query:
        #     if term in self.index.df.keys():                
        #         term_frequencies = dict(pls[term.lower()])                
        #         if doc_id in term_frequencies.keys():            
        #             freq = term_frequencies[doc_id]
        #             numerator = self.idf[term] * freq * (self.k1 + 1)
        #             denominator = freq + self.k1 * (1 - self.b + self.b * doc_len / self.AVGDL)
        #             score += (numerator / denominator)
        for term in query:
            if term in self.index.df.keys():                
                term_frequencies = dict(pls[term.lower()])
                relevent_docs =  intersection(docs,[doc_id for doc_id,tf in term_frequencies.items()])
                for doc_id in relevent_docs:
                    tf = term_frequencies[doc_id]
                    numerator = self.idf[term] * tf * (self.k1 + 1)
                    denominator = tf + self.k1 * (1 - self.b + self.b * self.DL[str(doc_id)] / self.AVGDL)
                    scores[doc_id] += (numerator / denominator)

                # for doc_id,tf in term_frequencies:            
                #   if (doc_id in docs):
                #     numerator = self.idf[term] * tf * (self.k1 + 1)
                #     denominator = tf + self.k1 * (1 - self.b + self.b * self.DL[str(doc_id)] / self.AVGDL)
                #     scores[doc_id] += (numerator / denominator)
        return scores

# %%
bm25_body = BM25_from_index(body_index,body_DL)
# for lst in bm25_title.pls:
#   if 1 in lst:
#     print(lst)
quety_terms_lst=[q.lower().split() for q,docs in queries_to_docs_raw.items()]
query2doc_bm25=bm25_body.search(quety_terms_lst,N=40)

# %% [markdown]
# # Estimate

# %%
#@title Default title text
def intersection(l1,l2):      
    """
    This function perform an intersection between two lists.

    Parameters
    ----------
    l1: list of documents. Each element is a doc_id.
    l2: list of documents. Each element is a doc_id.

    Returns:
    ----------
    list with the intersection (without duplicates) of l1 and l2
    """
    return list(builtins.set(l1)&builtins.set(l2))
def precision_at_k(true_list,predicted_list,k=40):    
    """
    This function calculate the precision@k metric.

    Parameters
    -----------
    true_list: list of relevant documents. Each element is a doc_id.
    predicted_list: sorted list of documents predicted as relevant. Each element is a doc_id. Sorted is performed by relevance score
    k: integer, a number to slice the length of the predicted_list
    
    Returns:
    -----------
    float, precision@k with 3 digits after the decimal point.
    """      
    # YOUR CODE HERE

    up=len(intersection(predicted_list[:k],true_list))
    down=k
    return builtins.round(up/down,3)

def average_precision(true_list,predicted_list,k=40):
    """
    This function calculate the average_precision@k metric.(i.e., precision in every recall point).     

    Parameters
    -----------
    true_list: list of relevant documents. Each element is a doc_id.
    predicted_list: sorted list of documents predicted as relevant. Each element is a doc_id. Sorted is performed by relevance score
    k: integer, a number to slice the length of the predicted_list
    
    Returns:
    -----------
    float, average precision@k with 3 digits after the decimal point.
    """
    # YOUR CODE HERE
    # for each relevant doc that in pl and in tl activate p@k and sum them,after 
    #devide by number of relevant
    sum=0
    rel=len(intersection(predicted_list[:k],true_list))
    if rel==0:
      return 0
    for i_pl,doc in enumerate(predicted_list[:k]):
      if doc in true_list:
        sum+=precision_at_k(true_list,predicted_list[:k],i_pl+1)
    return builtins.round(sum/rel,3)

def mean_ap(true_dict,predicted_dict,k=40):
  sum=0
  for q_id,true_lst in true_dict.items():
    sum+=average_precision(true_lst,predicted_dict[q_id])
  return sum/len(true_dict)

# %%
qid_to_true_docs_dict={i:d[1] for i,d in enumerate(queries_to_docs_raw.items())}
qid_to_returned_docs_dict={i:t for i,t in D.items()}
res={qid:[k for k,v in tl] for qid,tl in qid_to_returned_docs_dict.items()}
map_cosim_body=mean_ap(qid_to_true_docs_dict,res)


bm25_dict={qid:[doc for doc,s in lst] for qid,lst in query2doc_bm25.items()}
map_bm25_body=mean_ap(qid_to_true_docs_dict,bm25_dict,40)
# average_precision(q_tokenes_dict[0],cosine_sim_result[0])

# %%
print('cosine simularity strategy MAP@40 score: '+str(map_cosim_body))
print('bm25 strategy MAP@40 score: '+str(map_bm25_body))
# Out:
# cosine simularity strategy MAP@40 score: 0.06726666666666667
# bm25 strategy MAP@40 score: 0.5086666666666666

# %%
qid_to_returned_docs_dict={i:t for i,t in D.items()}
res={qid:[k for k,v in tl] for qid,tl in qid_to_returned_docs_dict.items()}
map_cosim_body=mean_ap(qid_to_true_docs_dict,res)
print('cosine simularity strategy MAP@40 score: '+str(map_cosim_body))

# bm25_dict={qid:[doc for doc,s in lst] for qid,lst in query2doc_bm25.items()}
# map_bm25_body=mean_ap(qid_to_true_docs_dict,bm25_dict,40)
# average_precision(q_tokenes_dict[0],cosine_sim_result[0])
# print('bm25 strategy MAP@40 score: '+str(map_bm25_body))

# %%
sum=0
for id in qid_to_true_docs_dict[0]:
  if id in qid_to_returned_docs_dict[0]:
    sum+=1
    print(id)
print(sum)
